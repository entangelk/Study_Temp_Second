# %% [markdown]
# <a href="https://colab.research.google.com/github/entangelk/Study_Temp_Second/blob/main/docs/analysis/yohan/seventh_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install konlpy

import warnings

# 경고 메시지를 무시하도록 설정
warnings.filterwarnings("ignore")

import pandas as pd
from konlpy.tag import Okt

# 최종 최적화 군집 수
get_list = [4,3,3,2,8,2,3,2,5,3,2,10,7,4,2,10,4,6,2,3,2,6,2,2,2,3,2,10,9,10,7,2,10,6,10,3,2,2,2,2,4,5,2,10,4,10,10,4,2,9,2,2,7,2,8,2,2,3]
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)

# %%
# 모든 데이터 로드
df_bibim1 = pd.read_csv("./local.bibim1.csv")
df_bibim2 = pd.read_csv("./local.bibim2.csv")
df_bibim3 = pd.read_csv("./local.bibim3.csv")
df_bibim4 = pd.read_csv("./local.bibim4.csv")

df_oil1 = pd.read_csv("./local.oil1.csv")
df_oil2 = pd.read_csv("./local.oil2.csv")
df_oil3 = pd.read_csv("./local.oil3.csv")
df_oil4 = pd.read_csv("./local.oil4.csv")
df_oil5 = pd.read_csv("./local.oil5.csv")

df_ham1 = pd.read_csv("./local.ham1.csv")
df_ham2 = pd.read_csv("./local.ham2.csv")
df_ham3 = pd.read_csv("./local.ham3.csv")
df_ham4 = pd.read_csv("./local.ham4.csv")
df_ham5 = pd.read_csv("./local.ham5.csv")

df_kyoja1 = pd.read_csv("./local.kyoja1.csv")
df_kyoja2 = pd.read_csv("./local.kyoja2.csv")
df_kyoja3 = pd.read_csv("./local.kyoja3.csv")
df_kyoja4 = pd.read_csv("./local.kyoja4.csv")

df_tomato1 = pd.read_csv("./local.tomato1.csv")
df_tomato2 = pd.read_csv("./local.tomato2.csv")
df_tomato3 = pd.read_csv("./local.tomato3.csv")

df_canola1 = pd.read_csv("./ssg.canola_oil1.csv")
df_canola2 = pd.read_csv("./ssg.canola_oil2.csv")
df_canola3 = pd.read_csv("./ssg.canola_oil3.csv")
df_canola4 = pd.read_csv("./ssg.canola_oil4.csv")

df_kimchi1 = pd.read_csv("./ssg.kimchi1.csv")
df_kimchi2 = pd.read_csv("./ssg.kimchi2.csv")
df_kimchi3 = pd.read_csv("./ssg.kimchi3.csv")
df_kimchi4 = pd.read_csv("./ssg.kimchi4.csv")

df_mung_bean_sprouts1 = pd.read_csv("./ssg.mung_bean_sprouts1.csv")
df_mung_bean_sprouts2 = pd.read_csv("./ssg.mung_bean_sprouts2.csv")
df_mung_bean_sprouts3 = pd.read_csv("./ssg.mung_bean_sprouts3.csv")
df_mung_bean_sprouts4 = pd.read_csv("./ssg.mung_bean_sprouts4.csv")

df_pancake_powder1 = pd.read_csv("./ssg.pancake_powder1.csv")
df_pancake_powder2 = pd.read_csv("./ssg.pancake_powder2.csv")
df_pancake_powder3 = pd.read_csv("./ssg.pancake_powder3.csv")
df_pancake_powder4 = pd.read_csv("./ssg.pancake_powder4.csv")

df_rice1 = pd.read_csv("./ssg.rice1.csv")
df_rice2 = pd.read_csv("./ssg.rice2.csv")
df_rice3 = pd.read_csv("./ssg.rice3.csv")
df_rice4 = pd.read_csv("./ssg.rice4.csv")
df_rice5 = pd.read_csv("./ssg.rice5.csv")

df_bread1 = pd.read_csv("./local.bread_1.csv")
df_bread2 = pd.read_csv("./local.bread_2.csv")
df_bread3 = pd.read_csv("./local.bread_3.csv")
df_bread4 = pd.read_csv("./local.bread_4.csv")

df_cheese1 = pd.read_csv("./local.cheese_1.csv")
df_cheese2 = pd.read_csv("./local.cheese_2.csv")
df_cheese3 = pd.read_csv("./local.cheese_3.csv")

df_milk1 = pd.read_csv("./local.milk_1.csv")
df_milk2 = pd.read_csv("./local.milk_2.csv")
df_milk3 = pd.read_csv("./local.milk_3.csv")

df_water1 = pd.read_csv("./local.water_1.csv")
df_water2 = pd.read_csv("./local.water_2.csv")
df_water3 = pd.read_csv("./local.water_3.csv")

df_yogurt1 = pd.read_csv("./local.yogurt_1.csv")
df_yogurt2 = pd.read_csv("./local.yogurt_2.csv")
df_yogurt3 = pd.read_csv("./local.yogurt_3.csv")

dfs = [df_bibim1,df_bibim2,df_bibim3,df_bibim4,df_oil1,df_oil2,df_oil3,df_oil4,df_oil5,df_ham1,df_ham2,df_ham3,df_ham4,df_ham5,df_kyoja1,df_kyoja2,df_kyoja3,df_kyoja4,df_tomato1,df_tomato2,df_tomato3,df_canola1,df_canola2,df_canola3,df_canola4,df_kimchi1,df_kimchi2,df_kimchi3,df_kimchi4,df_mung_bean_sprouts1,df_mung_bean_sprouts2,df_mung_bean_sprouts3,df_mung_bean_sprouts4,df_pancake_powder1,df_pancake_powder2,df_pancake_powder3,df_pancake_powder4,df_rice1,df_rice2,df_rice3,df_rice4,df_rice5,df_bread1,df_bread2,df_bread3,df_bread4,df_cheese1,df_cheese2,df_cheese3,df_milk1,df_milk2,df_milk3,df_water1,df_water2,df_water3,df_yogurt1,df_yogurt2,df_yogurt3]

# %%
# 전처리 작업 함수 적용

# 3점을 제외한 나머지 라벨링 작업 함수 제작
def labeling(text):
    if text in [4,5]:
        text = 1
    elif text in [1,2]:
        text = 0
    else:
        pass
    return text



def compare_data(dfs_list,labeling_fuc):
    counter = 0
    save_data_list = []
    for i in dfs_list:
        # db저장시 발생했던 고유값 제거
        i = i.drop(columns = '_id')

        # 라벨링 함수 적용
        i['textLevel'] = i['textLevel'].apply(labeling_fuc)


        # 딥러닝이슈로 인한 중간값 제외
        processing_df = i.query('textLevel != 3')

        # 듀플 제거전 긍정/부정 갯수 카운트
        posi_count = processing_df[processing_df['textLevel'] == 1].shape[0]
        naga_count = processing_df[processing_df['textLevel'] == 0].shape[0]

        # 중복값 제거
        processing_df = processing_df.drop_duplicates()

        deldu_posi_count = processing_df[processing_df['textLevel'] == 1].shape[0]
        deldu_naga_count = processing_df[processing_df['textLevel'] == 0].shape[0]

        # print(f'{i["merchTitle"][0]} 제품의 제거전 긍정문의 갯수 : {posi_count}')
        # print(f'{i["merchTitle"][0]} 제품의 제거전 부정문의 갯수 : {naga_count}')
        # print(f'{i["merchTitle"][0]} 제품의 제거후 긍정문의 갯수 : {deldu_posi_count}')
        # print(f'{i["merchTitle"][0]} 제품의 제거후 긍정문의 갯수 : {deldu_naga_count}')

        # 2차원 리스트로 저장
        append_list = [posi_count,naga_count,deldu_posi_count,deldu_naga_count]
        save_data_list.append(append_list)

        counter += 1
        if counter != len(dfs_list):
            # print('')
            pass

    return save_data_list

# %%
save_data_list = compare_data(dfs,labeling)

# %%
# 기본적인 불용어와 상표명 등의 독립단어 설정
stopword1 = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게','의','가','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']
stopword2 = ['팔도','팔도비빔면','비빔면','괄도','네넴띤','괄도네넴띤','농심','배홍동','배홍동비빔면','오뚜기','진비빔면','삼양','찰비빔면','비비고','교자','왕교자','노브랜드','교자만두','만두','왕교자만두','피코크','담백한왕교자','토마토','청정원','파스타소스','폰타나','샘표','뽀모도로','CJ','cj','스팸','클래식','덴마크튤립햄','튤립햄','동원','리챔','하림','닭가슴살햄','챔','더본코리아','빽햄','백종원','고소한참기름','참기름','경천','경천식품','시골참기름','들기름','최순희','백설','통참깨참기름','통참깨','임금님','임금님표','이천쌀','한눈에 반한 쌀','경기미','농협','농협양곡','당진해나루쌀','삼광','의성','의성농협','바른고을','의성진쌀','김치','별미총각김치','총각김치','종가집','종가','오래오래맛있는총각김치','조선호텔특제육수','조선호텔','부침가루','부침','곰표','통감자','자연주의','숙주나물','친환경','국산숙주','숙주','무농약','통통숙주','카놀라유','카놀라오일','카놀라','Coosur','coosur','쿡투게더','부드러운우유식빵','식빵','우유식빵','삼립','롯데','롯데웰푸드','기린','우유','더 메나쥬리','메나쥬리','온가족우유식빵','삼다수','에비앙','백산수','플레인','요거트','덴마크','에치와이','hy','윌','상하','상하치즈','체다','치즈','서울우유','서울','슬라이스','남양','드빈치','체다치즈','갓밀크','굿모닝','굿밀크','헬로우','앙팡']
stopword = stopword1 + stopword2

# %%
# Okt 형태소 분석기 인스턴스 생성
okt = Okt()

import re
import numpy as np


# 토크나이징 함수 정의
def tokenizer(raw, pos=["Noun","Alpha","Verb","Number"], stopword=stopword):

  get_list = []

  for word, tag in okt.pos(raw,norm=True,stem=True):
    if len(word) <= 1:
      word = '공란'

    if tag in pos and word not in stopword:
      get_list.append(word)
    else:
      get_list.append('공란')
    pass


  return get_list

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(tokenizer=tokenizer, use_idf=True)

# %% [markdown]
# ## 최적화된 군집으로 LDA 진행

# %%
# 추출 함수 제작

def LDAs(vectorizer,input_text_list,n_compo):

  features = vectorizer.fit_transform(input_text_list)

  # 단어 사전 추출
  dictionary_list = vectorizer.get_feature_names_out()

  # LDA 학습
  from sklearn.decomposition import LatentDirichletAllocation
  lda_model = LatentDirichletAllocation(n_components=n_compo, random_state=55) #인스턴스화 #n_components 토픽의 갯수
  lda_model.fit(features) #교육

  ## 상위 단어 추출
  ## 0 확률 1은 dictionary
  topics_list = list()
  for topic in lda_model.components_:
      df_datas = [topic, dictionary_list]
      df_topics = pd.DataFrame(data=df_datas)
      df_topics= df_topics.T
      df_topics = df_topics.sort_values(0, ascending=False)

      topics_text = ' '.join(df_topics[1].values[:10])# 시리즈 형식으로 출력 get values from series / index
      topics_list.append(topics_text)

  return topics_list

# %%
get_topics = []
counter = 0
for i in range(len(dfs)):
  # db저장시 발생했던 고유값 제거
  dfs[i] = dfs[i].drop(columns = '_id')

  # 라벨링 함수 적용
  dfs[i]['textLevel'] = dfs[i]['textLevel'].apply(labeling)

  # 긍정문 추출
  processing_df = dfs[i].query('textLevel == 1')

  # 토픽 추출
  try:
    get_topics.append(LDAs(vectorizer,processing_df['textContent'],get_list[i]))
  except:
    get_topics.append(f'오류 발생 : {counter}번재 csv')

  counter += 1

# %%
# csv 별 토픽 추출
total_counter = 0
for i in get_list:
  list_counter = 0
  for j in range(i):
    list_counter += 1
    print(f'{dfs[total_counter]["merchTitle"][0]} {list_counter}번째 토픽 : {get_topics[total_counter][j]}')

  total_counter += 1

  print('--------------------------------------')
# Out:
# 팔도비빔면 130g*4개 1번째 토픽 : 공란 먹다 자다 재다 여름 아주 비비다 시키다 삼겹살 겨울
# 팔도비빔면 130g*4개 2번째 토픽 : 공란 배송 받다 감사하다 제품 항상 자다 상품 애용 구매
# 팔도비빔면 130g*4개 3번째 토픽 : 공란 가격 구입 추천 넣다 골뱅이 되다 품질 대비 간식
# 팔도비빔면 130g*4개 4번째 토픽 : 공란 구매 자주 역시 여름 최고 상품 제품 제일 아이
# --------------------------------------
# 농심 배홍동비빔면 4입 1번째 토픽 : 공란 배송 배홍 감사하다 매콤 최고 제일 않다 애용 콤달콤
# 농심 배홍동비빔면 4입 2번째 토픽 : 공란 주문 사다 재다 배홍 여름 먹다 가격 동이 사보다
# 농심 배홍동비빔면 4입 3번째 토픽 : 공란 구매 먹다 자다 자주 제품 항상 상품 받다 구입
# --------------------------------------
# 오뚜기 진비빔면156g*4 1번째 토픽 : 공란 구매 제품 양도 자주 매콤 배송 항상 감사하다 사다
# 오뚜기 진비빔면156g*4 2번째 토픽 : 공란 먹다 자다 받다 보다 역시 시키다 다른 매번 양념
# 오뚜기 진비빔면156g*4 3번째 토픽 : 공란 상품 구입 최고 재다 잇다 가성 나다 싸다 진짜
# --------------------------------------
# 농심 찰비빔면 (130g*4입) 1번째 토픽 : 공란 구매 배송 자주 받다 항상 제품 상품 가격 감사하다
# 농심 찰비빔면 (130g*4입) 2번째 토픽 : 공란 먹다 자다 여름 사다 매콤 싸다 최고 제일 보다
# --------------------------------------
# 오뚜기 고소한참기름320ml(병) 1번째 토픽 : 공란 사다 재다 싸다 자다 양도 쓰기 요리 먹다 넣다
# 오뚜기 고소한참기름320ml(병) 2번째 토픽 : 공란 쓰다 최고 참깨 되다 짜다 통깨 먹다 국산 생각
# 오뚜기 고소한참기름320ml(병) 3번째 토픽 : 공란 믿다 사먹다 먹다 시키다 그냥 뚜기 잇다 항상 자주
# 오뚜기 고소한참기름320ml(병) 4번째 토픽 : 공란 구매 항상 제품 자주 상품 애용 주문 먹다 매번
# 오뚜기 고소한참기름320ml(병) 5번째 토픽 : 공란 배송 감사하다 추천 품질 상품 포장 오다 용량 가격
# 오뚜기 고소한참기름320ml(병) 6번째 토픽 : 공란 구입 사용 이용 제품 항상 기름 자주 나다 자다
# 오뚜기 고소한참기름320ml(병) 7번째 토픽 : 공란 받다 자다 먹다 아주 배송 잘쓰다 진해 상품 크다
# 오뚜기 고소한참기름320ml(병) 8번째 토픽 : 공란 먹다 역시 가성 무난 제일 가격 들다 써다 고소
# --------------------------------------
# 시골참기름 300ml(병) 1번째 토픽 : 공란 구매 제품 자주 시골 구입 애용 보다 처음 먹다
# 시골참기름 300ml(병) 2번째 토픽 : 공란 먹다 항상 가격 자다 상품 받다 배송 주문 가성
# --------------------------------------
# [피코크] 국산 참기름 250ml 1번째 토픽 : 공란 제품 사다 항상 믿다 구매 국산 애용 국내 사먹다
# [피코크] 국산 참기름 250ml 2번째 토픽 : 공란 국산 믿다 먹다 구매 가격 구입 참깨 않다 코크
# [피코크] 국산 참기름 250ml 3번째 토픽 : 공란 자다 배송 자주 상품 받다 감사하다 구매 먹다 품질
# --------------------------------------
# 최순희 참기름300ml(병) 1번째 토픽 : 공란 구매 자주 배송 제품 자다 항상 감사하다 상품 받다
# 최순희 참기름300ml(병) 2번째 토픽 : 공란 먹다 구입 않다 재다 사다 사용 중국산 국산 용기
# --------------------------------------
# 백설 통참깨참기름300ml(병) 1번째 토픽 : 공란 구매 자주 제품 항상 상품 구입 애용 먹다 처음
# 백설 통참깨참기름300ml(병) 2번째 토픽 : 공란 참깨 주문 배송 가격 재다 품질 아주 추천 않다
# 백설 통참깨참기름300ml(병) 3번째 토픽 : 공란 먹다 통깨 자다 무난 가격 대비 짜다 참깨 행사
# 백설 통참깨참기름300ml(병) 4번째 토픽 : 공란 받다 자다 사다 사용 쓰다 싸다 믿다 감사하다 기름
# 백설 통참깨참기름300ml(병) 5번째 토픽 : 공란 감사하다 가성 배송 들다 정말 생각 시키다 나다 상품
# --------------------------------------
# [CJ] 스팸 클래식 200g 1번째 토픽 : 공란 먹다 사다 짜다 굽다 볶음밥 가끔 잇다 넣다 반찬
# [CJ] 스팸 클래식 200g 2번째 토픽 : 공란 자다 배송 자주 구매 역시 받다 상품 최고 가격
# [CJ] 스팸 클래식 200g 3번째 토픽 : 공란 항상 제품 감사하다 구매 부대찌개 먹다 주문 애용 먹기
# --------------------------------------
# 농심 덴마크튤립햄 클래식 200g 1번째 토픽 : 공란 구매 배송 먹다 않다 항상 제품 상품 자주 짜지다
# 농심 덴마크튤립햄 클래식 200g 2번째 토픽 : 공란 자다 받다 사다 구입 가격 먹다 짜다 가성 싸다
# --------------------------------------
# 동원 리챔 200g 1번째 토픽 : 공란 먹다 자주 자다 구매 상품 굽다 믿다 아주 만족
# 동원 리챔 200g 2번째 토픽 : 배송 감사하다 공란 이마트 항상 기사 려고 감사 친절 생각나다
# 동원 리챔 200g 3번째 토픽 : 공란 짜다 채다 먹다 잇다 보다 김밥 제일 사용 넣다
# 동원 리챔 200g 4번째 토픽 : 않다 공란 짜지다 채다 먹기 시키다 진짜 짠맛 가격 가성
# 동원 리챔 200g 5번째 토픽 : 공란 구입 아이 매번 재다 낫다 무난 우리 자다 사먹다
# 동원 리챔 200g 6번째 토픽 : 비상 굿굿 대신 품질 공란 사이즈 맞다 입맛 편이 고기
# 동원 리챔 200g 7번째 토픽 : 공란 가격 대비 다음 사보다 파다 들다 두다 구비 음식
# 동원 리챔 200g 8번째 토픽 : 공란 제품 항상 주문 반찬 구매 먹다 애용 최고 자주
# 동원 리챔 200g 9번째 토픽 : 공란 구매 받다 자다 사다 상품 부대찌개 싸다 볶음밥 넣다
# 동원 리챔 200g 10번째 토픽 : 공란 먹기 먹다 짜다 역시 가끔 다른 굽다 나다 반찬
# --------------------------------------
# 하림 닭가슴살햄 챔200g 1번째 토픽 : 공란 구매 자주 자다 사다 상품 배송 싸다 그냥 들다
# 하림 닭가슴살햄 챔200g 2번째 토픽 : 공란 행사 구매 원뿔 김밥 즐기다 먹다 해보다 품질 보고
# 하림 닭가슴살햄 챔200g 3번째 토픽 : 공란 제품 항상 구매 자주 먹기 아주 감사하다 일반 먹다
# 하림 닭가슴살햄 챔200g 4번째 토픽 : 공란 짜다 생각 주문 건강 만해 먹다 할인 기름기 대신
# 하림 닭가슴살햄 챔200g 5번째 토픽 : 공란 받다 배송 감사하다 자다 먹다 시키다 안심 매번 쓰다
# 하림 닭가슴살햄 챔200g 6번째 토픽 : 공란 먹다 가슴 않다 짜지다 보다 다이어트 지방 구매 사보다
# 하림 닭가슴살햄 챔200g 7번째 토픽 : 공란 살이 가슴 구입 만족 조금 기름 먹다 행사 마음
# --------------------------------------
# 백종원의 빽햄(200g) 1번째 토픽 : 공란 구매 자다 자주 사다 먹다 상품 항상 주문 믿다
# 백종원의 빽햄(200g) 2번째 토픽 : 공란 해봤다 역시 나다 최고 만족 배송 끓이다 찌게 구매
# 백종원의 빽햄(200g) 3번째 토픽 : 공란 재다 가성 되다 사먹다 기대 돼지 적다 보다 국산
# 백종원의 빽햄(200g) 4번째 토픽 : 공란 먹다 짜다 않다 감사하다 배송 짜지다 받다 보다 제품
# --------------------------------------
# [비비고] 왕교자1.12kg 1번째 토픽 : 공란 먹다 구매 자주 제품 항상 자다 상품 받다 최고
# [비비고] 왕교자1.12kg 2번째 토픽 : 공란 배송 역시 감사하다 왕교 제일 구입 냉동 사다 애용
# --------------------------------------
# 노브랜드 교자만두1000g 1번째 토픽 : 오
# 노브랜드 교자만두1000g 2번째 토픽 : 류
# 노브랜드 교자만두1000g 3번째 토픽 :
# 노브랜드 교자만두1000g 4번째 토픽 : 발
# 노브랜드 교자만두1000g 5번째 토픽 : 생
# 노브랜드 교자만두1000g 6번째 토픽 :
# 노브랜드 교자만두1000g 7번째 토픽 : :
# 노브랜드 교자만두1000g 8번째 토픽 :
# 노브랜드 교자만두1000g 9번째 토픽 : 1
# 노브랜드 교자만두1000g 10번째 토픽 : 5
# --------------------------------------
# BIG 왕교자만두1000g 1번째 토픽 : 공란 가성 구매 자주 제품 가격 항상 양도 최고 먹다
# BIG 왕교자만두1000g 2번째 토픽 : 공란 가격 대비 먹다 속이다 싸다 아주 먹기 찌다 굽다
# BIG 왕교자만두1000g 3번째 토픽 : 공란 자다 받다 배송 먹다 감사하다 사다 상품 파다 추천
# BIG 왕교자만두1000g 4번째 토픽 : 공란 크다 애용 무난 굿굿 제품 크기 자주 정말 사보다
# --------------------------------------
# 피코크 담백한왕교자490g*2 1번째 토픽 : 공란 구매 자주 상품 제품 항상 무난 아주 구입 믿다
# 피코크 담백한왕교자490g*2 2번째 토픽 : 공란 가격 코크 재다 대비 않다 왕교 잇다 아이 최고
# 피코크 담백한왕교자490g*2 3번째 토픽 : 공란 먹다 찌다 사다 굽다 행사 사보다 먹기 생각 구매
# 피코크 담백한왕교자490g*2 4번째 토픽 : 공란 먹다 자다 받다 감사하다 애용 배송 주문 보다 자주
# 피코크 담백한왕교자490g*2 5번째 토픽 : 공란 배송 가성 왕교 상품 이용 만족 속도 이마트 에어
# 피코크 담백한왕교자490g*2 6번째 토픽 : 공란 크다 피코 속이다 나다 싸다 먹다 꽉차다 고기 냄새
# --------------------------------------
# 오뚜기 파스타소스(토마토) 600g 1번째 토픽 : 공란 소스 스파게티 먹다 무난 사다 파스타 프레스코 만들다 제일
# 오뚜기 파스타소스(토마토) 600g 2번째 토픽 : 공란 구매 항상 제품 자주 자다 상품 가격 받다 배송
# --------------------------------------
# 청정원 파스타소스 600g(토마토) 1번째 토픽 : 공란 먹다 자다 스파게티 받다 사다 가격 소스 이용 양도
# 청정원 파스타소스 600g(토마토) 2번째 토픽 : 공란 파스타 소스 배송 청정 감사하다 만들다 먹기 제일 피자
# 청정원 파스타소스 600g(토마토) 3번째 토픽 : 공란 구매 자주 제품 항상 상품 구입 아이 무난 애용
# --------------------------------------
# 폰타나 뽀모도로 파스타 소스 600g 1번째 토픽 : 공란 소스 파스타 자다 배송 스파게티 먹다 받다 상품 사다
# 폰타나 뽀모도로 파스타 소스 600g 2번째 토픽 : 공란 구매 제품 항상 자주 먹다 구입 행사 주문 토마토소스
# --------------------------------------
# 노브랜드 카놀라유 1L 1번째 토픽 : 공란 배송 받다 감사하다 자다 구입 이용 제품 믿다 처음
# 노브랜드 카놀라유 1L 2번째 토픽 : 공란 먹다 양도 최고 품질 시키다 자다 가격 보다 가성
# 노브랜드 카놀라유 1L 3번째 토픽 : 공란 가격 싸다 대비 아주 추천 잘쓰다 입구 가성 뚜껑
# 노브랜드 카놀라유 1L 4번째 토픽 : 공란 가성 사다 브랜드 놀라다 사용 튀김 자다 쓰다 기름
# 노브랜드 카놀라유 1L 5번째 토픽 : 공란 용량 재다 크다 가격 커서 의사 오르다 입구 만족
# 노브랜드 카놀라유 1L 6번째 토픽 : 공란 구매 자주 상품 제품 항상 가성 주문 매번 쓸다
# --------------------------------------
# 백설 카놀라오일900ml 1번째 토픽 : 공란 구매 제품 자다 항상 사다 구입 자주 가격 배송
# 백설 카놀라오일900ml 2번째 토픽 : 공란 놀라다 받다 감사하다 요리 튀김 식용유 기름 사용 용량
# --------------------------------------
# Coosur 카놀라오일1L 1번째 토픽 : 공란 가성 자다 놀라다 싸다 받다 사용 구입 튀김 양도
# Coosur 카놀라오일1L 2번째 토픽 : 공란 구매 가격 제품 배송 사다 자주 항상 상품 감사하다
# --------------------------------------
# [쿡투게더] 카놀라유 1L 1번째 토픽 : 공란 자다 배송 구매 먹다 제품 사다 사용 구입 가격
# [쿡투게더] 카놀라유 1L 2번째 토픽 : 감사하다 공란 주문 기름 요리 잘살다 쓰기 않다 쏘다 추천
# --------------------------------------
# 노브랜드 별미총각김치 1.5kg 1번째 토픽 : 공란 먹다 자다 배송 받다 감사하다 가격 익히다 최고 정말
# 노브랜드 별미총각김치 1.5kg 2번째 토픽 : 공란 익다 오다 사먹다 사다 먹기 않다 이번 먹다 무가
# 노브랜드 별미총각김치 1.5kg 3번째 토픽 : 공란 구매 자주 제품 항상 브랜드 주문 가성 상품 재다
# --------------------------------------
# CJ 비비고 총각김치 1.5KG 1번째 토픽 : 공란 구매 먹다 자주 제품 항상 익히다 상품 정말 제일
# CJ 비비고 총각김치 1.5KG 2번째 토픽 : 공란 자다 익다 배송 먹다 받다 감사하다 주문 재다 최고
# --------------------------------------
# [종가] 오래오래맛있는총각김치 1.5kg 1번째 토픽 : 공란 익다 오다 무가 가성 이번 살다 먹기 총각 먹다
# [종가] 오래오래맛있는총각김치 1.5kg 2번째 토픽 : 공란 먹다 아주 나다 두다 익다 익히다 진짜 조금 보다
# [종가] 오래오래맛있는총각김치 1.5kg 3번째 토픽 : 공란 최고 구입 가격 갓집 먹다 믿다 정말 대비 지다
# [종가] 오래오래맛있는총각김치 1.5kg 4번째 토픽 : 공란 재다 추천 행사 의사 않다 짜지다 구매 만족 보내다
# [종가] 오래오래맛있는총각김치 1.5kg 5번째 토픽 : 공란 주문 오래오래 무난 계속 먹다 처음 잇다 가장 짜다
# [종가] 오래오래맛있는총각김치 1.5kg 6번째 토픽 : 공란 제일 사먹다 이용 맞다 들다 먹다 되다 자주 아이
# [종가] 오래오래맛있는총각김치 1.5kg 7번째 토픽 : 공란 구매 자주 항상 제품 상품 주문 애용 먹다 시키다
# [종가] 오래오래맛있는총각김치 1.5kg 8번째 토픽 : 자다 공란 받다 감사하다 먹다 배송 사다 싸다 상품 물건
# [종가] 오래오래맛있는총각김치 1.5kg 9번째 토픽 : 공란 배송 상품 품질 무우 이마트 상태 드리다 적다 해주다
# [종가] 오래오래맛있는총각김치 1.5kg 10번째 토픽 : 공란 익히다 역시 먹다 넘다 갓집 양도 강추 빠지다 살짝
# --------------------------------------
# 피코크 조선호텔특제육수 총각김치 1.5kg 1번째 토픽 : 공란 익다 아주 먹다 오다 라면 바로 금방 살짝 느낌
# 피코크 조선호텔특제육수 총각김치 1.5kg 2번째 토픽 : 공란 먹다 자다 익히다 입맛 맞다 사먹다 무가 제일 양념
# 피코크 조선호텔특제육수 총각김치 1.5kg 3번째 토픽 : 받다 공란 자다 파다 쓰다 26일 그냥 어울리다 조산 계속
# 피코크 조선호텔특제육수 총각김치 1.5kg 4번째 토픽 : 공란 대비 생것 가격 마다 대박 매우 모말 모네 살다
# 피코크 조선호텔특제육수 총각김치 1.5kg 5번째 토픽 : 공란 코크 호텔 조선 역시 육수 잇다 peacock 조금 최고
# 피코크 조선호텔특제육수 총각김치 1.5kg 6번째 토픽 : 배송 공란 감사하다 정말 해주다 가격 자다 구입 예정 쓰다
# 피코크 조선호텔특제육수 총각김치 1.5kg 7번째 토픽 : 재다 공란 의사 최고 반찬 인정 보다 먹다 잘삿어용 만들다
# 피코크 조선호텔특제육수 총각김치 1.5kg 8번째 토픽 : 공란 호텔 조선 구매 자주 항상 상품 제품 주문 먹다
# 피코크 조선호텔특제육수 총각김치 1.5kg 9번째 토픽 : 공란 되다 익히다 냉장고 먹다 살다 하루 정도 넣다 감다
# --------------------------------------
# 자연주의 친환경 숙주나물 200g 1번째 토픽 : 공란 먹다 사다 상태 주의 자연 볶음 무치다 믿다 요리
# 자연주의 친환경 숙주나물 200g 2번째 토픽 : 공란 가격 오다 대비 양은 정말 사용 제품 자다 적지
# 자연주의 친환경 숙주나물 200g 3번째 토픽 : 공란 쌀국수 먹다 넣다 나물 아이 반찬 잇다 먹음 구매
# 자연주의 친환경 숙주나물 200g 4번째 토픽 : 공란 자다 받다 배송 감사하다 먹다 가성 상품 굿굿 물건
# 자연주의 친환경 숙주나물 200g 5번째 토픽 : 공란 양도 품질 싸다 살다 않다 시키다 먹다 배달 라면
# 자연주의 친환경 숙주나물 200g 6번째 토픽 : 공란 재다 포장 적다 의사 배송 무난 계속 상태 상품
# 자연주의 친환경 숙주나물 200g 7번째 토픽 : 공란 구매 자주 제품 상품 항상 구입 믿다 이용 매번
# 자연주의 친환경 숙주나물 200g 8번째 토픽 : 공란 주문 샤브샤브 추천 먹다 만족 최고 넣다 자주 항상
# 자연주의 친환경 숙주나물 200g 9번째 토픽 : 공란 국산 먹기 아주 한번 들다 소량 농약 신선 사먹다
# 자연주의 친환경 숙주나물 200g 10번째 토픽 : 공란 애용 이마트 항상 콩나물 제품 차돌 가끔 되다 상품
# --------------------------------------
# 풀무원 무농약 국산숙주 260g 1번째 토픽 : 공란 구매 자주 제품 상품 가격 아이 아주 이용 반찬
# 풀무원 무농약 국산숙주 260g 2번째 토픽 : 공란 국산 농약 믿다 사다 먹다 구매 무치다 안심 나다
# 풀무원 무농약 국산숙주 260g 3번째 토픽 : 공란 주문 샤브샤브 재다 매번 추천 먹다 사먹다 항상 자주
# 풀무원 무농약 국산숙주 260g 4번째 토픽 : 공란 항상 배송 제품 애용 상태 구매 오다 살다 상품
# 풀무원 무농약 국산숙주 260g 5번째 토픽 : 공란 자다 받다 감사하다 구입 먹다 배송 양도 최고 상품
# 풀무원 무농약 국산숙주 260g 6번째 토픽 : 공란 풀무원 국산 사용 믿다 먹다 들다 싸다 농약 넘다
# 풀무원 무농약 국산숙주 260g 7번째 토픽 : 공란 먹다 넣다 쌀국수 볶음 볶다 나물 시키다 차돌박이 라면
# --------------------------------------
# CJ 100% 국산숙주250g 1번째 토픽 : 공란 배송 자다 자주 상품 감사하다 항상 받다 제품 구매
# CJ 100% 국산숙주250g 2번째 토픽 : 공란 먹다 구매 국산 주문 오다 매번 믿다 않다 볶다
# --------------------------------------
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 1번째 토픽 : 공란 자다 받다 배송 감사하다 먹다 오다 구입 정말 제품
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 2번째 토픽 : 공란 먹다 넣다 쌀국수 볶다 진짜 라면 믿다 소고기 대비
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 3번째 토픽 : 공란 추천 가격 아주 들다 식감 먹다 할인 되다 넣다
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 4번째 토픽 : 공란 시키다 먹다 무치다 잇다 않다 살다 차돌박이 굿굿 볶음
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 5번째 토픽 : 공란 양도 가성 볶음 먹기 차돌 최고 삭해 삼겹살 가격
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 6번째 토픽 : 재다 통통 공란 의사 먹음 몰다 아주 양은 쌀국수 양적
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 7번째 토픽 : 공란 구매 자주 제품 상품 구입 항상 사용 요조 무난
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 8번째 토픽 : 공란 사다 샤브샤브 상태 요리 먹다 싸다 자다 나물 볶음
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 9번째 토픽 : 공란 항상 상품 주문 구매 이용 매번 제품 배송 먹다
# 풀무원 소가 아삭함이 오래가는 통통숙주 260g 10번째 토픽 : 공란 애용 제품 기한 풀무원 유통 삭함 항상 가다 이마트
# --------------------------------------
# [오뚜기] 부침가루 1kg 1번째 토픽 : 공란 부침개 배송 사다 이용 먹다 재다 싸다 해먹 최고
# [오뚜기] 부침가루 1kg 2번째 토픽 : 공란 가격 지퍼 양도 대비 되어다 되다 부치다 간이 품질
# [오뚜기] 부침가루 1kg 3번째 토픽 : 공란 부치다 가루 무난 역시 가성 제일 먹다 바삭 써다
# [오뚜기] 부침가루 1kg 4번째 토픽 : 공란 구입 떨어지다 배송 오다 이마트 행사 포장 않다 자주
# [오뚜기] 부침가루 1kg 5번째 토픽 : 공란 자다 먹다 받다 감사하다 상품 배송 구매 사다 매번
# [오뚜기] 부침가루 1kg 6번째 토픽 : 공란 제품 구매 항상 자주 애용 주문 상품 믿다 사용
# --------------------------------------
# CJ 백설 5가지재료 부침가루1kg 1번째 토픽 : 공란 부치다 가루 먹다 김치전 무난 부추 지퍼 제일 먹기
# CJ 백설 5가지재료 부침가루1kg 2번째 토픽 : 공란 배송 재다 최고 추천 가성 상품 이마트 잘쓰다 모두
# CJ 백설 5가지재료 부침가루1kg 3번째 토픽 : 공란 바삭 되다 부치다 밀가루 들다 행사 사먹다 첨가 가루
# CJ 백설 5가지재료 부침가루1kg 4번째 토픽 : 공란 재료 자연 믿다 부치다 가루 아주 구매 얻다 구입
# CJ 백설 5가지재료 부침가루1kg 5번째 토픽 : 공란 제품 항상 구매 구입 쓰다 사용 먹다 전부 믿다
# CJ 백설 5가지재료 부침가루1kg 6번째 토픽 : 공란 자다 받다 가격 사다 싸다 먹다 배송 대비 품질
# CJ 백설 5가지재료 부침가루1kg 7번째 토픽 : 공란 구매 자주 상품 정말 역시 튀김 구입 아이 먹다
# CJ 백설 5가지재료 부침가루1kg 8번째 토픽 : 공란 부침개 먹다 해먹 써다 만들다 양도 명절 나다 사다
# CJ 백설 5가지재료 부침가루1kg 9번째 토픽 : 공란 애용 주문 항상 제품 살다 자주 상품 시키다 되어다
# CJ 백설 5가지재료 부침가루1kg 10번째 토픽 : 감사하다 공란 이용 배송 매번 받다 자주 오다 상품 즐기다
# --------------------------------------
# 곰표 부침가루 1kg(레트로) 1번째 토픽 : 공란 먹다 구입 감사하다 부침개 가성 바삭 배송 재다 받다
# 곰표 부침가루 1kg(레트로) 2번째 토픽 : 공란 사다 가격 포장 싸다 자다 양도 대비 패키지 쓰다
# 곰표 부침가루 1kg(레트로) 3번째 토픽 : 공란 구매 부치다 가루 제품 자주 상품 항상 자다 배송
# --------------------------------------
# [백설] 통감자를 갈아넣은 바삭 부침가루 1kg 1번째 토픽 : 공란 바삭 부치다 가루 감자 넣다 가격 정말 통감 재다
# [백설] 통감자를 갈아넣은 바삭 부침가루 1kg 2번째 토픽 : 공란 먹다 구매 자다 제품 배송 자주 항상 받다 상품
# --------------------------------------
# [특등급] 임금님표 이천쌀 10kg 1번째 토픽 : 공란 먹다 밥맛 이천 역시 차다 윤기 시키다 최고 아주
# [특등급] 임금님표 이천쌀 10kg 2번째 토픽 : 공란 구매 항상 자다 배송 제품 상품 가격 받다 자주
# --------------------------------------
# 한눈에 반한 쌀 10kg 1번째 토픽 : 공란 구매 먹다 밥맛 항상 제품 자주 한눈 반한 구입
# 한눈에 반한 쌀 10kg 2번째 토픽 : 공란 자다 배송 가격 먹다 차다 받다 주문 사다 정말
# --------------------------------------
# [23년산]경기미10kg 1번째 토픽 : 공란 먹다 구매 자다 배송 자주 사다 제품 항상 감사하다
# [23년산]경기미10kg 2번째 토픽 : 공란 밥맛 가격 기미 받다 구입 차다 햅쌀 재다 윤기
# --------------------------------------
# [23년산]당진해나루쌀 삼광 10kg 1번째 토픽 : 공란 구매 배송 사다 감사하다 제품 가격 할인 항상 자다
# [23년산]당진해나루쌀 삼광 10kg 2번째 토픽 : 공란 자주 구매 재다 상품 주문 처음 가성 구입 윤기
# [23년산]당진해나루쌀 삼광 10kg 3번째 토픽 : 공란 먹다 밥맛 차다 나루 상태 진해 당진 도정 자다
# [23년산]당진해나루쌀 삼광 10kg 4번째 토픽 : 공란 받다 자다 일해 배송 아주 항상 애용 먹다 품질
# --------------------------------------
# 바른고을 의성진쌀 10kg 1번째 토픽 : 공란 무난 처음 사보다 정말 먹다 그냥 구매 보다 해봤다
# 바른고을 의성진쌀 10kg 2번째 토픽 : 공란 가격 대비 진쌀 밥맛 품질 아주 않다 햅쌀 최고
# 바른고을 의성진쌀 10kg 3번째 토픽 : 공란 구입 항상 주문 제품 먹다 가성 애용 싸다 매번
# 바른고을 의성진쌀 10kg 4번째 토픽 : 공란 먹다 배송 자다 밥맛 감사하다 받다 차다 윤기 나다
# 바른고을 의성진쌀 10kg 5번째 토픽 : 공란 구매 자주 상품 사다 재다 제품 자다 항상 행사
# --------------------------------------
# 부드러운우유식빵 BL 1번째 토픽 : 공란 먹다 자다 구매 상품 받다 제품 자주 항상 주문
# 부드러운우유식빵 BL 2번째 토픽 : 공란 배송 감사하다 오다 재다 먹기 구입 찌그러지다 않다 의사
# --------------------------------------
# 삼립 소화가잘되는우유가들어간식빵420g 1번째 토픽 : 공란 아이 주문 싸다 먹다 새벽 아침식사 420 빵집 쓰다
# 삼립 소화가잘되는우유가들어간식빵420g 2번째 토픽 : 공란 자다 먹다 받다 감사하다 사다 배송 최고 가격 일반
# 삼립 소화가잘되는우유가들어간식빵420g 3번째 토픽 : 공란 되다 소화 이용 간식 자다 자주 쏘다 구매 일해
# 삼립 소화가잘되는우유가들어간식빵420g 4번째 토픽 : 공란 재다 사먹다 나다 들어가다 들다 의사 만족 자주 역시
# 삼립 소화가잘되는우유가들어간식빵420g 5번째 토픽 : 공란 아주 가성 무난 애용 제일 나서다 제품 마트 모르다
# 삼립 소화가잘되는우유가들어간식빵420g 6번째 토픽 : 공란 배송 추천 잇다 그냥 유통 기한 상태 품질 상품
# 삼립 소화가잘되는우유가들어간식빵420g 7번째 토픽 : 공란 구입 가격 대비 냄새 생각 제과점 행사 제품 가성
# 삼립 소화가잘되는우유가들어간식빵420g 8번째 토픽 : 공란 구매 자주 제품 항상 상품 주문 매번 살다 믿다
# 삼립 소화가잘되는우유가들어간식빵420g 9번째 토픽 : 공란 토스트 먹다 먹기 굽다 포장 발라 버터 번창 굿굿
# 삼립 소화가잘되는우유가들어간식빵420g 10번째 토픽 : 공란 샌드위치 아침 먹다 시키다 토스트 오다 만들다 대용 먹기
# --------------------------------------
# [기린] 우유식빵 400g 1번째 토픽 : 공란 구매 자주 제품 항상 먹기 상품 무난 토스트 아이
# [기린] 우유식빵 400g 2번째 토픽 : 공란 구입 애용 아침 재다 가성 아주 생각 먹다 항상
# [기린] 우유식빵 400g 3번째 토픽 : 공란 먹다 토스트 자다 사다 주문 그냥 샌드위치 싸다 시키다
# [기린] 우유식빵 400g 4번째 토픽 : 공란 배송 받다 감사하다 가격 자다 대비 최고 이용 상품
# --------------------------------------
# [더 메나쥬리]온가족우유식빵 385g 1번째 토픽 : 공란 먹기 크기 무난 아침 아주 사먹다 샌드위치 토스트 자주
# [더 메나쥬리]온가족우유식빵 385g 2번째 토픽 : 공란 배송 쥬리 상품 아이 새벽 간식 조금 자주 넘다
# [더 메나쥬리]온가족우유식빵 385g 3번째 토픽 : 공란 감사하다 사다 가격 자다 배송 싸다 살다 대비 받다
# [더 메나쥬리]온가족우유식빵 385g 4번째 토픽 : 공란 사이즈 품질 추천 가족 만족 사용 예정 이상 가격
# [더 메나쥬리]온가족우유식빵 385g 5번째 토픽 : 공란 구매 제품 항상 자주 애용 먹다 않다 믿다 시키다
# [더 메나쥬리]온가족우유식빵 385g 6번째 토픽 : 공란 받다 그냥 최고 먹다 잇다 발라 배송 자다 진짜
# [더 메나쥬리]온가족우유식빵 385g 7번째 토픽 : 공란 먹다 자다 구입 토스트 먹음 굽다 않다 일해 샌드위치
# [더 메나쥬리]온가족우유식빵 385g 8번째 토픽 : 공란 생각 나다 정말 유통 기한 약간 아침식사 냉동 쫄깃
# [더 메나쥬리]온가족우유식빵 385g 9번째 토픽 : 공란 재다 매번 의사 상품 주문 처음 식감 사이즈 계속
# [더 메나쥬리]온가족우유식빵 385g 10번째 토픽 : 주문 공란 항상 작고 가끔 버터 프렌치토스트 먹다 구매 해봤다
# --------------------------------------
# 상하 체다 슬라이스 20매(360g) 1번째 토픽 : 공란 자주 구매 상품 제품 매번 먹다 항상 행사 가로
# 상하 체다 슬라이스 20매(360g) 2번째 토픽 : 공란 않다 짜지다 라이스 아주 20 30 함량 최애 자연
# 상하 체다 슬라이스 20매(360g) 3번째 토픽 : 공란 자다 받다 사다 먹다 가성 배송 넘다 사서 진짜
# 상하 체다 슬라이스 20매(360g) 4번째 토픽 : 공란 가격 구입 샌드위치 재다 먹다 넣다 일해 대비 정말
# 상하 체다 슬라이스 20매(360g) 5번째 토픽 : 공란 제품 항상 구매 추가 애용 증정 이용 10 먹다
# 상하 체다 슬라이스 20매(360g) 6번째 토픽 : 공란 배송 아이 감사하다 들다 간식 할인 구매 먹다 품목
# 상하 체다 슬라이스 20매(360g) 7번째 토픽 : 공란 주문 싸다 짜다 최고 용량 나다 굿굿 먹다 이마트
# 상하 체다 슬라이스 20매(360g) 8번째 토픽 : 공란 먹다 시키다 제일 그냥 넣다 보다 한장 라면 즐기다
# 상하 체다 슬라이스 20매(360g) 9번째 토픽 : 공란 먹기 무난 추천 사먹다 잇다 먹다 하나 요리 여기저기
# 상하 체다 슬라이스 20매(360g) 10번째 토픽 : 공란 양도 행사 믿다 구매 매일 두다 먹다 냉장고 역시
# --------------------------------------
# [서울우유] 체다 슬라이스 치즈 360g 1번째 토픽 : 공란 항상 제품 먹다 구매 않다 싸다 믿다 짜다 가장
# [서울우유] 체다 슬라이스 치즈 360g 2번째 토픽 : 공란 샌드위치 먹다 넣다 가격 주문 배송 토스트 무난 먹기
# [서울우유] 체다 슬라이스 치즈 360g 3번째 토픽 : 공란 자다 구매 자주 받다 상품 제품 감사하다 먹다 구입
# [서울우유] 체다 슬라이스 치즈 360g 4번째 토픽 : 공란 먹다 아이 제일 라이스 애용 간식 양도 최고 역시
# --------------------------------------
# 남양 드빈치 체다치즈 340g 1번째 토픽 : 공란 가격 구매 제품 자주 상품 오다 항상 붙다 배송
# 남양 드빈치 체다치즈 340g 2번째 토픽 : 공란 먹다 않다 짜지다 자다 아이 받다 사다 짜다 구입
# --------------------------------------
# 갓밀크 1L(멸균) 1번째 토픽 : 공란 기한 유통 멸균 가성 기다 최고 뚜껑 생각 사보다
# 갓밀크 1L(멸균) 2번째 토픽 : 공란 자다 받다 먹다 사다 아주 배송 구매 사용 포인트
# 갓밀크 1L(멸균) 3번째 토픽 : 공란 보관 멸균 나다 특유 두다 분유 먹다 기한길 말다
# 갓밀크 1L(멸균) 4번째 토픽 : 공란 만족 멸균 유통기간 모르다 마시다 즐기다 가장 폴란드 외국
# 갓밀크 1L(멸균) 5번째 토픽 : 공란 보다 처음 싸다 먹다 라떼 정말 만들다 계속 멸균
# 갓밀크 1L(멸균) 6번째 토픽 : 공란 감사하다 항상 제품 배송 구매 상품 주문 먹다 애용
# 갓밀크 1L(멸균) 7번째 토픽 : 공란 가격 대비 재다 아이 이용 품질 의사 배송 매번
# 갓밀크 1L(멸균) 8번째 토픽 : 공란 자주 구매 배송 상품 추천 제품 구입 살다 애용
# 갓밀크 1L(멸균) 9번째 토픽 : 공란 밀크 오다 해봤다 시키다 멸균 종종 구매 먹다 굿굿
# --------------------------------------
# 노브랜드 굿모닝 굿밀크 1L(한정물량 생산으로 조기품절 가능) 1번째 토픽 : 공란 구매 가성 자주 가격 제품 배송 브랜드 상품 항상
# 노브랜드 굿모닝 굿밀크 1L(한정물량 생산으로 조기품절 가능) 2번째 토픽 : 공란 먹다 자다 감사하다 받다 항상 사다 배송 싸다 아주
# --------------------------------------
# [서울우유] 헬로우 앙팡 우유 1000ml 1번째 토픽 : 공란 아이 먹다 사다 아기 주문 우리 간식 추천 마시다
# [서울우유] 헬로우 앙팡 우유 1000ml 2번째 토픽 : 공란 먹다 자다 구매 항상 상품 제품 자주 받다 배송
# --------------------------------------
# 삼다수 500ml 1번째 토픽 : 공란 역시 최고 생수 추천 들다 먹기 넘다 우리 먹다
# 삼다수 500ml 2번째 토픽 : 공란 받다 자다 재다 감사하다 배송 상품 아주 먹다 휴대
# 삼다수 500ml 3번째 토픽 : 공란 물맛 500 다니다 외출 사무실 들다 감사 ml 하나
# 삼다수 500ml 4번째 토픽 : 공란 마시다 믿다 생수 먹다 제일 물이 항상 말다 제주
# 삼다수 500ml 5번째 토픽 : 공란 주문 시키다 항상 가격 이용 해주다 배달 자주 제품
# 삼다수 500ml 6번째 토픽 : 공란 배송 감사하다 사다 자다 싸다 할인 라벨 오다 행사
# 삼다수 500ml 7번째 토픽 : 공란 구매 제품 항상 자주 상품 구입 애용 먹다 매번
# --------------------------------------
# 에비앙 500ml 1번째 토픽 : 공란 배송 감사하다 구매 자다 항상 받다 자주 제품 상품
# 에비앙 500ml 2번째 토픽 : 공란 물맛 먹다 사다 구입 생수 마시다 가격 주문 물이
# --------------------------------------
# [농심] 백산수 500ml 1번째 토픽 : 받다 자다 공란 말다 감사하다 배송 추천 먹다 정말 사다
# [농심] 백산수 500ml 2번째 토픽 : 공란 구매 자주 상품 제품 구입 이용 싸다 행사 사다
# [농심] 백산수 500ml 3번째 토픽 : 공란 항상 제품 주문 먹다 구매 애용 물이 생수 사먹다
# [농심] 백산수 500ml 4번째 토픽 : 공란 마시다 믿다 산수 휴대 배달 생수 500 역시 마시기
# [농심] 백산수 500ml 5번째 토픽 : 공란 감사하다 배송 아주 살다 해주다 먹기 보다 사무실 상품
# [농심] 백산수 500ml 6번째 토픽 : 공란 산수 물맛 가격 배송 최고 사다 생수 제일 품질
# [농심] 백산수 500ml 7번째 토픽 : 공란 들다 외출 다니다 하나 가지 감사 나가다 드리다 마음
# [농심] 백산수 500ml 8번째 토픽 : 공란 매번 시키다 먹다 가성 아이 무난 만족 갈다 주문
# --------------------------------------
# [노브랜드] 플레인 요거트 450g 1번째 토픽 : 공란 먹다 구매 자주 가성 자다 받다 감사하다 사다 상품
# [노브랜드] 플레인 요거트 450g 2번째 토픽 : 공란 가격 제품 항상 배송 않다 브랜드 양도 주문 대비
# --------------------------------------
# 덴마크 떠먹는 요거트 플레인 450g 1번째 토픽 : 공란 먹다 구매 않다 배송 자다 감사하다 제품 받다 자주
# 덴마크 떠먹는 요거트 플레인 450g 2번째 토픽 : 공란 먹기 가격 달다 구입 다음 양도 아주 처음 최고
# --------------------------------------
# hy 떠먹는 윌 450g 1번째 토픽 : 공란 먹다 뜨다 마시다 추천 구입 가격 재다 주문 처음
# hy 떠먹는 윌 450g 2번째 토픽 : 공란 구매 제품 자주 아주 상품 항상 먹다 사다 아침
# hy 떠먹는 윌 450g 3번째 토픽 : 배송 공란 자다 감사하다 받다 들다 매번 상품 먹다 드리다
# --------------------------------------

# %%
import pickle

with open("./topics.pkl", "wb") as f:
    pickle.dump(get_topics, f)
